# %%
import matplotlib.pyplot as plt 
import numpy as np 
import math

# plt.plot(X, y, color='r', label='sin') 
# plt.plot(X, z, color='g', label='cos')
plt.figure(1)
x,y = np.loadtxt('2-5.xvg',comments=["@","#"],unpack=True)
w,z = np.loadtxt('2-5_true_control.xvg',comments=["@","#"],unpack=True)
plt.plot(x,y, color='red', label='OpenFF')
plt.plot(w,z, color='blue', label='MacRog')
plt.xlabel("Degrees")
plt.ylabel("Probability Density ($nm^{-1}$)")
plt.legend()
plt.title("C-C Dihedral: 2-5")
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180])

plt.figure(2)
l,m = np.loadtxt('doubleBond_od_dihed_POPC.xvg',comments=["@","#"],unpack=True)
o,p = np.loadtxt('db_true_control.xvg',comments=["@","#"],unpack=True)
plt.plot(l,m, color='red', label='OpenFF')
plt.plot(o,p, color='blue', label='MacRog')
plt.xlabel("Degrees")
plt.ylabel("Probability Density ($nm^{-1}$)")
plt.legend()
plt.title("C-C Dihedral: Double Bond +2")
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180])

plt.figure(3)
t,d = np.loadtxt('11-14.xvg',comments=["@","#"],unpack=True)
j,k = np.loadtxt('11-14_true_control.xvg',comments=["@","#"],unpack=True)
plt.plot(t,d, color='red', label='OpenFF')
plt.plot(j,k, color='blue', label='MacRog')
plt.xlabel("Degrees")
plt.ylabel("Probability Density ($nm^{-1}$)")
plt.legend()
plt.title("C-C Dihedral: 11-14")
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);

# %%
# plt.plot(X, y, color='r', label='sin') 
# plt.plot(X, z, color='g', label='cos')
plt.figure(1)
x,y = np.loadtxt('a71_a75_POPC.xvg',comments=["@","#"],unpack=True)
w,z = np.loadtxt('a71_a75_POPC_true.xvg',comments=["@","#"],unpack=True)
plt.plot(x,y, color='red', label='OpenFF')
plt.plot(w,z, color='blue', label='MacRog')
plt.xlabel("Degrees")
plt.ylabel("Probability Density ($nm^{-1}$)")
plt.legend()
plt.title("C-H Dihedral: 71 70 73 75 | HCCH")
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180])

plt.figure(2)
l,m = np.loadtxt('a72_a75_POPC.xvg',comments=["@","#"],unpack=True)
o,p = np.loadtxt('a72_a75_POPC_true.xvg',comments=["@","#"],unpack=True)
plt.plot(l,m, color='red', label='OpenFF')
plt.plot(o,p, color='blue', label='MacRog')
plt.xlabel("Degrees")
plt.ylabel("Probability Density ($nm^{-1}$)")
plt.legend()
plt.title("C-H Dihedral: 72 70 73 75 | HCCH")
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180])

plt.figure(3)
t,d = np.loadtxt('a71_a76.xvg',comments=["@","#"],unpack=True)
j,k = np.loadtxt('a71_a76_true_control.xvg',comments=["@","#"],unpack=True)
plt.plot(t,d, color='red', label='OpenFF')
plt.plot(j,k, color='blue', label='MacRog')
plt.xlabel("Degrees")
plt.ylabel("Probability Density ($nm^{-1}$)")
plt.legend()
plt.title("C-H Dihedral: 71 70 73 76 | HCCC")
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180])

plt.figure(4)
q,r = np.loadtxt('a72_a76.xvg',comments=["@","#"],unpack=True)
s,t = np.loadtxt('a72_a76_true_control.xvg',comments=["@","#"],unpack=True)
plt.plot(q,r, color='red', label='OpenFF')
plt.plot(s,t, color='blue', label='MacRog')
plt.xlabel("Degrees")
plt.ylabel("Probability Density ($nm^{-1}$)")
plt.legend()
plt.title("C-H Dihedral: 72 70 73 76 | HCCC")
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);

# %%
plt.figure(1)
x,y = np.loadtxt('DispCorr_cutoff_POPC.xvg',comments=["@","#"],unpack=True)
plt.plot(x,y)
xlabel("Time (ps)")
ylabel("(kJ/mol)")
plt.xticks([0,50000,100000,150000,200000])
plt.xlim(0,200000)
plt.title("Dispersion Correction OpenFF Cutoff")

plt.figure(2)
x,y = np.loadtxt('DispCorr_PME_POPC.xvg',comments=["@","#"],unpack=True)
plt.plot(x,y)
xlabel("Time (ps)")
ylabel("(kJ/mol)")
plt.xticks([0,50000,100000,150000,200000])
plt.xlim(0,200000)
plt.title("Dispersion Correction OpenFF LJ-PME")
# Out:
# Text(0.5, 1.0, 'Dispersion Correction OpenFF LJ-PME')
