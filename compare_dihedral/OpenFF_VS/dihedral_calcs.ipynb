# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Double Bond

# *******************************
# ***** OpenFF calculations *****
# *******************************
# (Type 2)

phi_rad = np.linspace(-np.pi, np.pi, num=1000)
U = 13.197694603020*(1+np.cos(2*phi_rad-np.pi)) + -1.745204449790*(1+np.cos(1*phi_rad-np.pi))

# U = k*(1+np.cos(n*phi-phi0))

# peak at cos = 1

# *******************************
# ***** MacRog calculations *****
# *******************************
# (Type 3/9: Ryckaert-Bellemans function)

constants = [44.4498, -2.39164, -81.248, 8.87284, 34.797, -4.50675]
V = 0
n = 0

for C in constants:
        V += C*(np.cos(phi_rad-np.pi))**n
        n += 1

# HCCH
# C0 = 44.4498 | C1 = -2.39164 | C2 = -81.248 | C3 = 8.87284 | C4 = 34.797 | C5 = -4.50675

phi = np.linspace(-180, 180, num=1000)
plt.figure(1)
plt.plot(phi, U)
plt.plot(phi, V)
plt.xlabel("Degrees")
plt.ylabel("$V_d$ ($kJ mol^{-1}$)")
plt.title("Double Bond C-C Dihedral Potential | CCCC")
plt.plot(phi,U, color='red', label='OpenFF')
plt.plot(phi,V, color='blue', label='MacRog')
plt.legend()
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);

# %%
# 2-5
# OpenFF
phi_rad = np.linspace(-np.pi, np.pi, num=1000)
U = 1.796983533954*(1+np.cos(3*phi_rad-0)) + 1.064375944885*(1+np.cos(2*phi_rad-0)) + 3.655209445001*(1+np.cos(1*phi_rad-0))
# U = (1.796983533954+1.064375944885+3.655209445001)*(1+np.cos(3*phi_rad-2*(np.pi)))

# MacRog
constants = [1.81211, -0.948788, -3.15209, 1.32173, 4.32914, -3.39430]
V = 0
n = 0

for C in constants:
        V += C*(np.cos(phi_rad-np.pi))**n
        n += 1

# HCCH
# C0 = 1.81211 | C1 = -0.948788 | C2 = -3.15209 | C3 = 1.32173 | C4 = 4.32914 | C5 = -3.39430

phi = np.linspace(-180, 180, num=1000)
plt.figure(1)
plt.plot(phi, U)
plt.plot(phi, V)
plt.xlabel("Degrees")
plt.ylabel("$V_d$ ($kJ mol^{-1}$)")
plt.title("'2-5' / '11-14' C-C Dihedral Potential | CCCC")
plt.plot(phi,U, color='red', label='OpenFF')
plt.plot(phi,V, color='blue', label='MacRog')
plt.legend()
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);

# %%
# 11-14 (71/72    70    73    75)

# OpenFF
phi_rad = np.linspace(-np.pi, np.pi, num=1000)
U = 1.052724976165*(1+np.cos(3*phi_rad-0))

# MacRog
constants = [0.6276, 1.8828, 0, -2.5104, 0, 0]
V = 0
n = 0

for C in constants:
        V += C*(np.cos(phi_rad-np.pi))**n
        n += 1

# HCCH
# C0 = 0.6276 | C2 = 1.88280 | C3 = 0 | C4 = -2.51040 | C5 = 0 | C6 = 0

phi = np.linspace(-180, 180, num=1000)
plt.figure(1)
plt.plot(phi, U)
plt.plot(phi, V)
plt.xlabel("Degrees")
plt.ylabel("$V_d$ ($kJ mol^{-1}$)")
plt.title("C-H Dihedral Potential: 71/72 70 73 75 | HCCH ")
plt.plot(phi,U, color='red', label='OpenFF')
plt.plot(phi,V, color='blue', label='MacRog', linestyle='dashed')
plt.legend()
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);

# %%
# 11-14 (71/72    70    73    76)

# OpenFF
phi_rad = np.linspace(-np.pi, np.pi, num=1000)
U = 0.359275061834*(1+np.cos(3*phi_rad-0))

# MacRog
constants = [0.6276, 1.8828, 0, -2.5104, 0, 0]
V = 0
n = 0

for C in constants:
        V += C*(np.cos(phi_rad-np.pi))**n
        n += 1

# HCCH
# C0 = 0.6276 | C2 = 1.88280 | C3 = 0 | C4 = -2.51040 | C5 = 0 | C6 = 0

phi = np.linspace(-180, 180, num=1000)
plt.figure(1)
plt.plot(phi, U)
plt.plot(phi, V)
plt.xlabel("Degrees")
plt.ylabel("$V_d$ ($kJ mol^{-1}$)")
plt.title("C-H Dihedral Potential: 71/72 70 73 76 HCCC")
plt.plot(phi,U, color='red', label='OpenFF')
plt.plot(phi,V, color='blue', label='MacRog')
plt.legend()
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);
