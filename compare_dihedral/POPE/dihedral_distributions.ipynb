# %%
import matplotlib.pyplot as plt 
import numpy as np 
import math

plt.figure(1)
x,y = np.loadtxt('8_15_11_14_POPE.xvg',comments=["@","#"],unpack=True)
w,z = np.loadtxt('8_15_11_14_POPE_control.xvg',comments=["@","#"],unpack=True)
plt.plot(x,y, color='red', label='OpenFF')
plt.plot(w,z, color='blue', label='CHARMM36')
plt.xlabel("Degrees")
plt.ylabel("Probability Density")
plt.legend()
plt.title("Headgroup Dihedral | COPO")
# plt.xlim(-180, 180)
# plt.xticks([-180,-120,-60,0,60,120,180])

plt.figure(2)
l,m = np.loadtxt('8_15_11_13_POPE.xvg',comments=["@","#"],unpack=True)
o,p = np.loadtxt('8_15_11_13_POPE_control.xvg',comments=["@","#"],unpack=True)
plt.plot(l,m, color='red', label='OpenFF')
plt.plot(o,p, color='blue', label='CHARMM36')
plt.xlabel("Degrees")
plt.ylabel("Probability Density")
plt.legend()
plt.title("Headgroup Dihedral | COP=O")
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);

# plt.figure(3)
# t,d = np.loadtxt('11-14.xvg',comments=["@","#"],unpack=True)
# j,k = np.loadtxt('11-14_true_control.xvg',comments=["@","#"],unpack=True)
# plt.plot(t,d, color='red', label='OpenFF')
# plt.plot(j,k, color='blue', label='MacRog')
# plt.xlabel("Degrees")
# plt.ylabel("Probability Density ($nm^{-1}$)")
# plt.legend()
# plt.title("C-C Dihedral: 11-14")
# plt.xlim(-180, 180)
# plt.xticks([-180,-120,-60,0,60,120,180]);

# %%
plt.figure(1)
x,y = np.loadtxt('6_5_8_9_POPE.xvg',comments=["@","#"],unpack=True)
w,z = np.loadtxt('6_5_8_9_POPE_control.xvg',comments=["@","#"],unpack=True)
plt.plot(x,y, color='red', label='OpenFF')
plt.plot(w,z, color='blue', label='CHARMM36')
plt.xlabel("Degrees")
plt.ylabel("Probability Density")
plt.legend()
plt.title("⍺ HG Dihedral | HCCH")
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180])

plt.figure(2)
l,m = np.loadtxt('7_5_8_10_POPE.xvg',comments=["@","#"],unpack=True)
o,p = np.loadtxt('7_5_8_10_POPE_control.xvg',comments=["@","#"],unpack=True)
plt.plot(l,m, color='red', label='OpenFF')
plt.plot(o,p, color='blue', label='CHARMM36')
plt.xlabel("Degrees")
plt.ylabel("Probability Density")
plt.legend()
plt.title("⍺ HG Dihedral | HCCH")
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);
# Out:
# ([<matplotlib.axis.XTick at 0x11fe81c90>,
# ...
#  [Text(-180, 0, '−180'),
#   Text(-120, 0, '−120'),
#   Text(-60, 0, '−60'),
#   Text(0, 0, '0'),
#   Text(60, 0, '60'),
#   Text(120, 0, '120'),
#   Text(180, 0, '180')])
