# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
plt.figure(1)
# t123a
x,y = np.loadtxt('P1_O1_C2_H2_OFF_premade.xvg',comments=["@","#"],unpack=True)
i,s = np.loadtxt('P1_O1_C2_H2_OFF.xvg',comments=["@","#"],unpack=True)
w,z = np.loadtxt('P1_O1_C2_H2_macrog.xvg',comments=["@","#"],unpack=True)
a,b = np.loadtxt('P1_O1_C2_H2_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(x,y, color='black', label='OpenFF Prebuild')
plt.plot(i,s, color='#0333b0', label='OpenFF')
plt.plot(w,z, color='green', label='MacRog')
plt.plot(a,b, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("P-O1-C2-H2 (id='t123a')");
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);

plt.figure(2)
l,m = np.loadtxt('P1_O4_C3_H4_OFF_premade.xvg',comments=["@","#"],unpack=True)
u,q = np.loadtxt('P1_O4_C3_H4_OFF.xvg',comments=["@","#"],unpack=True)
o,p = np.loadtxt('P1_O4_C3_H4_macrog.xvg',comments=["@","#"],unpack=True)
c,d = np.loadtxt('P1_O4_C3_H4_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(l,m, color='black', label='OpenFF Prebuild')
plt.plot(u,q, color='#0333b0', label='OpenFF')
plt.plot(o,p, color='green', label='MacRog')
plt.plot(c,d, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("P-O4-C3-H4 (id='t123a')");
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);

plt.figure(3)
# t160
h,r = np.loadtxt('C2_O1_P1_O4_OFF_premade.xvg',comments=["@","#"],unpack=True)
t,d = np.loadtxt('C2_O1_P1_O4_OFF.xvg',comments=["@","#"],unpack=True)
j,k = np.loadtxt('C2_O1_P1_O4_macrog.xvg',comments=["@","#"],unpack=True)
e,f = np.loadtxt('C2_O1_P1_O4_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(h,r, color='black', label='OpenFF Prebuild')
plt.plot(t,d, color='#0333b0', label='OpenFF')
plt.plot(j,k, color='green', label='MacRog')
plt.plot(e,f, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("⍺C-O4-P-O1 (id='t160')");
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);

# %%
plt.figure(1)
# t159
x,y = np.loadtxt('C2_O1_P1_O3_OFF_premade.xvg',comments=["@","#"],unpack=True)
i,s = np.loadtxt('C2_O1_P1_O3_OFF.xvg',comments=["@","#"],unpack=True)
w,z = np.loadtxt('C2_O1_P1_O3_macrog.xvg',comments=["@","#"],unpack=True)
a,b = np.loadtxt('C2_O1_P1_O3_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(x,y, color='black', label='OpenFF Prebuild')
plt.plot(i,s, color='#0333b0', label='OpenFF')
plt.plot(w,z, color='green', label='MacRog')
plt.plot(a,b, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("C2-O1-P-O3 (id='t159')");
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);

plt.figure(2)
l,m = np.loadtxt('C1_C2_O1_P1_OFF_premade.xvg',comments=["@","#"],unpack=True)
u,q = np.loadtxt('C1_C2_O1_P1_OFF.xvg',comments=["@","#"],unpack=True)
o,p = np.loadtxt('C1_C2_O1_P1_macrog.xvg',comments=["@","#"],unpack=True)
c,d = np.loadtxt('C1_C2_O1_P1_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(l,m, color='black', label='OpenFF Prebuild')
plt.plot(u,q, color='#0333b0', label='OpenFF')
plt.plot(o,p, color='green', label='MacRog')
plt.plot(c,d, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees", fontsize=15)
plt.ylabel("Probability", fontsize=15)
plt.legend(fontsize=12)
plt.title("Phosphate Dihedral Distribution (C1-C2-O1-P)", fontsize=17);
plt.xlim(-180, 180)
plt.yticks([0.000,0.005,0.010,0.015,0.020,0.025], fontsize=12);
plt.xticks([-180,-120,-60,0,60,120,180], fontsize=12);
plt.savefig("RIGHT_HERE", dpi=700)
# ax.set_xlabel('Bond #', fontsize=21)
# ax.set_ylabel('% Isomerization', fontsize=21)
# ax.set_title('sn-1 Gauche Isomerization', fontsize=24)
# ax.legend(fontsize=14)
# ax.tick_params(axis='both', which='major', labelsize=18)
# ax.set_xticks(np.arange(1, len(percentages_dict[xvg_folders[0]]) + 1))

plt.figure(3)
# t160
h,r = np.loadtxt('C2_O1_P1_O2_OFF_premade.xvg',comments=["@","#"],unpack=True)
t,d = np.loadtxt('C2_O1_P1_O2_OFF.xvg',comments=["@","#"],unpack=True)
j,k = np.loadtxt('C2_O1_P1_O2_macrog.xvg',comments=["@","#"],unpack=True)
e,f = np.loadtxt('C2_O1_P1_O2_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(h,r, color='black', label='OpenFF Prebuild')
plt.plot(t,d, color='#0333b0', label='OpenFF')
plt.plot(j,k, color='green', label='MacRog')
plt.plot(e,f, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("C2-O1-P-O2 (id='t159')");
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);

# %%
plt.figure(1)
x,y = np.loadtxt('P1_O1_C2_H3_OFF_premade.xvg',comments=["@","#"],unpack=True)
i,s = np.loadtxt('P1_O1_C2_H3_OFF.xvg',comments=["@","#"],unpack=True)
w,z = np.loadtxt('P1_O1_C2_H3_macrog.xvg',comments=["@","#"],unpack=True)
a,b = np.loadtxt('P1_O1_C2_H3_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(x,y, color='black', label='OpenFF Prebuild')
plt.plot(i,s, color='#0333b0', label='OpenFF')
plt.plot(w,z, color='green', label='MacRog')
plt.plot(a,b, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("P-O1-C2-H3 (id='t123a')");
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);

plt.figure(2)
l,m = np.loadtxt('P1_O4_C3_C4_OFF_premade.xvg',comments=["@","#"],unpack=True)
u,q = np.loadtxt('P1_O4_C3_C4_OFF.xvg',comments=["@","#"],unpack=True)
o,p = np.loadtxt('P1_O4_C3_C4_macrog.xvg',comments=["@","#"],unpack=True)
c,d = np.loadtxt('P1_O4_C3_C4_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(l,m, color='black', label='OpenFF Prebuild')
plt.plot(u,q, color='#0333b0', label='OpenFF')
plt.plot(o,p, color='green', label='MacRog')
plt.plot(c,d, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("P-O4-C3-C4 (id='t123a')");
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);

plt.figure(3)
h,r = np.loadtxt('P1_O4_C3_H5_OFF_premade.xvg',comments=["@","#"],unpack=True)
t,d = np.loadtxt('P1_O4_C3_H5_OFF.xvg',comments=["@","#"],unpack=True)
j,k = np.loadtxt('P1_O4_C3_H5_macrog.xvg',comments=["@","#"],unpack=True)
e,f = np.loadtxt('P1_O4_C3_H5_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(h,r, color='black', label='OpenFF Prebuild')
plt.plot(t,d, color='#0333b0', label='OpenFF')
plt.plot(j,k, color='green', label='MacRog')
plt.plot(e,f, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("P-O4-C3-H5 (id='t123a')");
plt.xlim(-180, 180)
plt.xticks([-180,-120,-60,0,60,120,180]);
