# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
plt.figure(1)
x,y = np.loadtxt('O1_P1_O4_OFF_premade.xvg',comments=["@","#"],unpack=True)
i,s = np.loadtxt('O1_P1_O4_OFF.xvg',comments=["@","#"],unpack=True)
w,z = np.loadtxt('O1_P1_O4_macrog.xvg',comments=["@","#"],unpack=True)
a,b = np.loadtxt('O1_P1_O4_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(x,y, color='black', label='OpenFF Prebuild')
plt.plot(i,s, color='#0333b0', label='OpenFF')
plt.plot(w,z, color='green', label='MacRog')
plt.plot(a,b, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("O1-P-O4 (id='a40')");
# plt.xlim(-180, 180)
# plt.xticks([-180,-120,-60,0,60,120,180]);

plt.figure(2)
l,m = np.loadtxt('O2_P1_O3_OFF_premade.xvg',comments=["@","#"],unpack=True)
u,q = np.loadtxt('O2_P1_O3_OFF.xvg',comments=["@","#"],unpack=True)
o,p = np.loadtxt('O2_P1_O3_macrog.xvg',comments=["@","#"],unpack=True)
c,d = np.loadtxt('O2_P1_O3_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(l,m, color='black', label='OpenFF Prebuild')
plt.plot(u,q, color='#0333b0', label='OpenFF')
plt.plot(o,p, color='green', label='MacRog')
plt.plot(c,d, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("O2-P-O3 (id='a40')");
# plt.xlim(-180, 180)
# plt.xticks([-180,-120,-60,0,60,120,180]);

plt.figure(3)
h,r = np.loadtxt('O3_P1_O4_OFF_premade.xvg',comments=["@","#"],unpack=True)
t,d = np.loadtxt('O3_P1_O4_OFF.xvg',comments=["@","#"],unpack=True)
j,k = np.loadtxt('O3_P1_O4_macrog.xvg',comments=["@","#"],unpack=True)
e,f = np.loadtxt('O3_P1_O4_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(h,r, color='black', label='OpenFF Prebuild')
plt.plot(t,d, color='#0333b0', label='OpenFF')
plt.plot(j,k, color='green', label='MacRog')
plt.plot(e,f, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("O3-P-O4 (id='a40')");
# plt.xlim(-180, 180)
# plt.xticks([-180,-120,-60,0,60,120,180]);

# %%
plt.figure(1)
x,y = np.loadtxt('O1_P1_O3_OFF_premade.xvg',comments=["@","#"],unpack=True)
i,s = np.loadtxt('O1_P1_O3_OFF.xvg',comments=["@","#"],unpack=True)
w,z = np.loadtxt('O1_P1_O3_macrog.xvg',comments=["@","#"],unpack=True)
a,b = np.loadtxt('O1_P1_O3_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(x,y, color='black', label='OpenFF Prebuild')
plt.plot(i,s, color='#0333b0', label='OpenFF')
plt.plot(w,z, color='green', label='MacRog')
plt.plot(a,b, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("O1-P-O3 (id='a40')");
# plt.xlim(-180, 180)
# plt.xticks([-180,-120,-60,0,60,120,180]);

plt.figure(2)
l,m = np.loadtxt('O1_P1_O2_OFF_premade.xvg',comments=["@","#"],unpack=True)
u,q = np.loadtxt('O1_P1_O2_OFF.xvg',comments=["@","#"],unpack=True)
o,p = np.loadtxt('O1_P1_O2_macrog.xvg',comments=["@","#"],unpack=True)
c,d = np.loadtxt('O1_P1_O2_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(l,m, color='black', label='OpenFF Prebuild')
plt.plot(u,q, color='#0333b0', label='OpenFF')
plt.plot(o,p, color='green', label='MacRog')
plt.plot(c,d, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("O1-P-O2 (id='a40')");
# plt.xlim(-180, 180)
# plt.xticks([-180,-120,-60,0,60,120,180]);

plt.figure(3)
h,r = np.loadtxt('C2_O1_P1_OFF_premade.xvg',comments=["@","#"],unpack=True)
t,d = np.loadtxt('C2_O1_P1_OFF.xvg',comments=["@","#"],unpack=True)
j,k = np.loadtxt('C2_O1_P1_macrog.xvg',comments=["@","#"],unpack=True)
e,f = np.loadtxt('C2_O1_P1_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(h,r, color='black', label='OpenFF Prebuild')
plt.plot(t,d, color='#0333b0', label='OpenFF')
plt.plot(j,k, color='green', label='MacRog')
plt.plot(e,f, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("C2-O1-P (id='a28')");
# plt.xlim(-180, 180)
# plt.xticks([-180,-120,-60,0,60,120,180]);

# %%
plt.figure(1)
x,y = np.loadtxt('O2_P1_O4_OFF_premade.xvg',comments=["@","#"],unpack=True)
i,s = np.loadtxt('O2_P1_O4_OFF.xvg',comments=["@","#"],unpack=True)
w,z = np.loadtxt('O2_P1_O4_macrog.xvg',comments=["@","#"],unpack=True)
a,b = np.loadtxt('O2_P1_O4_slipids.xvg',comments=["@","#"],unpack=True)
# plt.plot(x,y, color='black', label='OpenFF Prebuild')
plt.plot(i,s, color='#0333b0', label='OpenFF')
plt.plot(w,z, color='green', label='MacRog')
plt.plot(a,b, color='#ee7f17', label='Slipids')
plt.xlabel("Degrees")
plt.ylabel("Probability")
plt.legend()
plt.title("O2-P-O4 (id='a40')");
# plt.xlim(-180, 180)
# plt.xticks([-180,-120,-60,0,60,120,180]);
